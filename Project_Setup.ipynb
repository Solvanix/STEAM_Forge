# %%
# Out:
# ✅ تم إنشاء جميع المجلدات بنجاح!

# %%
import os

# 🔹 تحديد مسارات المجلدات داخل WSL
base_path = "/mnt/c/Users/ali/Desktop/STEAM_Nexus_Hub/qr_code_workspace"
folders = ["Models", "Scripts", "Results"]

# 🔹 إنشاء المجلدات داخل المسار الصحيح
for folder in folders:
    os.makedirs(os.path.join(base_path, folder), exist_ok=True)

# 🔹 إنشاء مجلد "Site" داخل WSL
site_folder = "/mnt/c/Users/ali/Desktop/STEAM_Nexus_Hub/Site"
os.makedirs(site_folder, exist_ok=True)

print("✅ تم إنشاء جميع المجلدات بنجاح داخل WSL!")
# Out:
# ✅ تم إنشاء جميع المجلدات بنجاح داخل WSL!

# %%
# !cat .github/workflows/workflow.yml

# %%
git add .github/workflows/workflow.yml
git commit -m "تحديث workflow.yml لتصحيح الصياغة"
git push origin main  # استبدل `main` إذا كنت تعمل على فرع آخر

# %%
git add .github/workflows/workflow.yml && git commit -m "تحديث workflow.yml لتصحيح الصياغة" && git push origin main

# %%
# !git add .github/workflows/workflow.yml && git commit -m "تحديث workflow.yml لتصحيح الصياغة" && git push origin main

# %%
# !cat .github/workflows/workflow.yml

# %%
# !cat .github/workflows/workflow.yml

# %%
ls -R .github/

# %%
# !mkdir -p .github/workflows
# !touch .github/workflows/workflow.yml

# %%
# !cat .github/workflows/workflow.yml

# %%
# !git add .github/workflows/workflow.yml
# !git commit -m "إضافة إعدادات GitHub Actions لتثبيت المكتبات تلقائيًا"
# !git push origin main  # استبدل `main` إذا كنت تعمل على فرع آخر

# %%
# !git add .github/workflows/workflow.yml && git commit -m "إضافة إعدادات GitHub Actions لتثبيت المكتبات تلقائيًا" && git push origin main

# %%
# !cat .github/workflows/workflow.yml

# %%
import os

# تحديد المسار داخل WSL
base_path = "/mnt/c/Users/ali/Desktop/intro-to-ml-tensorflow"

# استعراض الملفات والمجلدات داخل جميع المستويات
for root, dirs, files in os.walk(base_path):
    print(root)
    for file in files:
        print(file)

# %%
# إنشاء ملف وإدخال البيانات داخل Jupyter Notebook
file_path = "/mnt/c/Users/ali/Desktop/STEAM_Nexus_Hub/Classification_of_flower_structure_TM1/Plant_Recognition_Lab/index.html"

# محتوى الصفحة
html_content = """
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Plant Recognition Lab</title>
</head>
<body>
    <h1>Welcome to Plant Recognition Lab</h1>
    <p>This project is part of the STEAM Nexus Hub and focuses on image classification of flower structures using TensorFlow.</p>
    <p>Explore the repository to find training models, structured documentation, and implementation details.</p>
</body>
</html>
"""

# كتابة البيانات إلى الملف
with open(file_path, "w") as file:
    file.write(html_content)

# تأكيد الإنشاء
print("File created successfully at:", file_path)

# %%
file_path = r"C:\Users\ali\Desktop\STEAM_Nexus_Hub\Classification_of_flower_structure_TM1\index.html"

html_content = """
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Flower Structure Classification</title>
</head>
<body>
    <h1>Welcome to Classification of Flower Structure TM1</h1>
    <p>This repository is part of the STEAM Nexus Hub, focusing on structured classification of flower structures.</p>
    <p>Navigate through models, datasets, and development resources.</p>
</body>
</html>
"""

with open(file_path, "w") as file:
    file.write(html_content)

print("File created successfully at:", file_path)

# %%
import os

# تحديد مسار الملف غير المطلوب
old_file = "/mnt/c/Users/ali/Desktop/STEAM_Nexus_Hub/Classification_of_flower_structure_TM1/Plant_Recognition_Lab/index.html"

# حذف الملف إذا كان موجودًا
if os.path.exists(old_file):
    os.remove(old_file)
    print("تم حذف الملف:", old_file)
else:
    print("الملف غير موجود، لا حاجة للحذف.")

# إنشاء ملف جديد في المسار الصحيح
new_file = "/mnt/c/Users/ali/Desktop/STEAM_Nexus_Hub/Classification_of_flower_structure_TM1/index.html"

html_content = """
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Flower Structure Classification</title>
</head>
<body>
    <h1>Welcome to Classification of Flower Structure TM1</h1>
    <p>This repository is part of the STEAM Nexus Hub, focusing on structured classification of flower structures.</p>
    <p>Navigate through models, datasets, and development resources.</p>
</body>
</html>
"""

# كتابة المحتوى إلى الملف الجديد
with open(new_file, "w") as file:
    file.write(html_content)

print("تم إنشاء الملف بنجاح في:", new_file)

# %%
import os

wrong_file = r"C:\Users\ali\Desktop\STEAM_Nexus_Hub\Classification_of_flower_structure_TM1\Plant_Recognition_Lab\CUsersaliDesktopSTEAM_Nexus_HubClassification_of_flower_structure_TM1\index.html"

if os.path.exists(wrong_file):
    os.remove(wrong_file)
    print("تم حذف المسار غير الصحيح:", wrong_file)
else:
    print("المسار غير موجود، لا حاجة للحذف.")

# %%
file_path = "/mnt/c/Users/ali/Desktop/STEAM_Nexus_Hub/Classification_of_flower_structure_TM1/index.html"

new_content = """
<section id="extra-content">
    <h2>مشاريع الذكاء الاصطناعي في الزراعة</h2>
    <p>يهدف هذا القسم إلى عرض أحدث التقنيات المستخدمة في تحليل المحاصيل وتحسين الإنتاج الزراعي.</p>
    <ul>
        <li>استخدام التعلم العميق لتحليل جودة النباتات</li>
        <li>تحسين عمليات الري باستخدام الذكاء الاصطناعي</li>
        <li>تطوير حلول مبتكرة للمزارعين</li>
    </ul>
</section>
"""

with open(file_path, "a") as file:
    file.write(new_content)

print("تمت إضافة المحتوى بنجاح إلى:", file_path)

# %%
file_path = "/mnt/c/Users/ali/Desktop/STEAM_Nexus_Hub/Classification_of_flower_structure_TM1/index.html"

# حذف محتوى الصفحة بالكامل
with open(file_path, "w") as file:
    file.write("")

# إعادة إنشاء المحتوى الجديد
new_content = """
<!DOCTYPE html>
<html lang="ar">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Smart Flavor Farm - الصفحة الرئيسية</title>
    <link rel="stylesheet" href="styles.css">
</head>
<body>

    <header>
        <h1>مشروع Smart Flavor Farm</h1>
        <p>منصة ذكاء اصطناعي لتحليل الغذاء وتحسين تجربة المستخدم</p>
    </header>

    <nav>
        <ul>
            <li><a href="Plant_Recognition_Lab/index.html">🔗 تصنيف النباتات</a></li>
            <li><a href="#classification">إدخال البيانات</a></li>
            <li><a href="#analysis">نتائج التحليل</a></li>
            <li><a href="#developer-access">تجربة المطور</a></li>
        </ul>
    </nav>

    <section id="user-choice">
        <h2>⚡ اختر طريقة الاستخدام</h2>
        <button onclick="redirectUser('visitor')">👤 الدخول كزائر</button>
        <button onclick="redirectUser('developer')">🛠️ الدخول كمطور</button>
    </section>

    <script>
        function redirectUser(role) {
            if (role === 'visitor') {
                window.location.href = "Plant_Recognition_Lab/index.html";
            } else {
                window.location.href = "developer-dashboard.html";
            }
        }
    </script>

</body>
</html>
"""

# كتابة المحتوى الجديد إلى الصفحة
with open(file_path, "w") as file:
    file.write(new_content)

print("تمت إعادة إنشاء الصفحة بنجاح في:", file_path)

# %%
file_path = "/mnt/c/Users/ali/Desktop/STEAM_Nexus_Hub/index.html"

html_content = """
<!DOCTYPE html>
<html lang="ar">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>مشاريع الذكاء الصناعي والابتكار - علي الخطيب</title>
    <link rel="stylesheet" href="styles.css">
</head>
<body>

    <header>
        <h1>مشاريع الابتكار الصناعي والذكاء الاصطناعي - علي الخطيب</h1>
        <p>الابتكار والتكنولوجيا لتحقيق مستقبل أكثر استدامة وذكاءً</p>
    </header>

    <section id="user-choice">
        <h2>اختر طريقة الاستخدام</h2>
        <button onclick="redirectUser('classification')">الدخول إلى تصنيف النباتات</button>
        <button onclick="redirectUser('plant_recognition')">الدخول إلى تحليل بنية النباتات</button>
        <button onclick="redirectUser('developer')">الدخول كمطور</button>
    </section>

    <nav>
        <ul>
            <li><a href="Classification_of_flower_structure_TM1/index.html">تصنيف بنية الزهور</a></li>
            <li><a href="Plant_Recognition_Lab/index.html">تحليل النباتات بالتعلم العميق</a></li>
            <li><a href="dashboard.html">لوحة التحكم</a></li>
            <li><a href="updates.html">آخر التحديثات</a></li>
        </ul>
    </nav>

    <section id="contact">
        <h2>اتصل بنا</h2>
        <div class="social-links">
            <a href="https://www.linkedin.com/in/ali-khateeb">LinkedIn</a>
            <a href="https://github.com/Ali-Khateeb">GitHub</a>
        </div>
        <p>البريد الإلكتروني: ali_alkhateeb91@hotmail.com</p>
        <p>الهاتف: +970 568033662</p>
    </section>

    <footer>
        <p>&copy; 2025 مركز التحكم في مشاريع الابتكار - جميع الحقوق محفوظة</p>
    </footer>

    <script>
        function redirectUser(role) {
            if (role == "classification") {
                window.location.href = "Classification_of_flower_structure_TM1/index.html";
            } elif (role == "plant_recognition") {
                window.location.href = "Plant_Recognition_Lab/index.html";
            } else {
                window.location.href = "developer-dashboard.html";
            }
        }
    </script>

</body>
</html>
"""

with open(file_path, "w") as file:
    file.write(html_content)

print("تم إنشاء أو تحديث الصفحة في:", file_path)

# %%
file_paths = [
    "/mnt/c/Users/ali/Desktop/STEAM_Nexus_Hub/Classification_of_flower_structure_TM1/index.html",
    "/mnt/c/Users/ali/Desktop/STEAM_Nexus_Hub/Classification_of_flower_structure_TM1/Plant_Recognition_Lab/index.html"
]

html_content = """
<!DOCTYPE html>
<html lang="ar">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>صفحة الدخول</title>
    <link rel="stylesheet" href="styles.css">
</head>
<body>

    <header>
        <h1>مرحبا بك في مشاريع الذكاء الصناعي</h1>
        <p>اختر طريقة الدخول:</p>
    </header>

    <section>
        <button onclick="redirectUser('visitor')">الدخول كمستخدم</button>
        <button onclick="redirectUser('developer')">الدخول كمطور</button>
    </section>

    <nav>
        <ul>
            <li><a href="../index.html">العودة إلى الصفحة الرئيسية</a></li>
            <li><a href="dashboard.html">لوحة التحكم</a></li>
            <li><a href="updates.html">آخر التحديثات</a></li>
        </ul>
    </nav>

    <script>
        function redirectUser(role) {
            if (role === 'visitor') {
                window.location.href = "user-dashboard.html";
            } else {
                window.location.href = "developer-dashboard.html";
            }
        }
    </script>

</body>
</html>
"""

for path in file_paths:
    with open(path, "w") as file:
        file.write(html_content)
    print("تم حفظ الملف في:", path)

# %%
file_paths = [
    "/mnt/c/Users/ali/Desktop/STEAM_Nexus_Hub/Classification_of_flower_structure_TM1/index.html",
    "/mnt/c/Users/ali/Desktop/STEAM_Nexus_Hub/Classification_of_flower_structure_TM1/Plant_Recognition_Lab/index.html"
]

new_content = """
<!DOCTYPE html>
<html lang="ar">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>إعداد المشروع - تخصيص النموذج</title>
    <link rel="stylesheet" href="styles.css">
</head>
<body>

    <header>
        <h1>إعداد المشروع - اختيار النموذج</h1>
        <p>قم بتخصيص طريقة تشغيل المشروع وفق احتياجاتك.</p>
    </header>

    <section>
        <h2>إعدادات التنفيذ</h2>
        <form>
            <label for="execution-selection">اختر طريقة التنفيذ:</label>
            <select id="execution-selection">
                <option value="gpu-high-accuracy">GPU - دقة عالية</option>
                <option value="cpu-balanced">CPU - متوازن</option>
                <option value="system-32">نظام 32 - تحليل دقيق</option>
                <option value="system-64">نظام 64 - أداء سريع</option>
            </select>
        </form>
    </section>

    <section>
        <h2>رفع البيانات</h2>
        <form>
            <label>حدد نوع البيانات:</label><br>
            <input type="checkbox" id="use-image" onchange="toggleInput()"> صورة  
            <input type="checkbox" id="use-video" onchange="toggleInput()"> فيديو  
            <input type="checkbox" id="use-text" onchange="toggleInput()"> نص  
            <br><br>

            <div id="image-section" style="display: none;">
                <label for="image-upload">تحميل صورة:</label>
                <input type="file" id="image-upload" accept="image/*" onchange="previewImage()">
                <img id="image-preview" style="max-width: 300px; display: none;">
            </div>

            <div id="video-section" style="display: none;">
                <label for="video-upload">تحميل فيديو:</label>
                <input type="file" id="video-upload" accept="video/*" onchange="previewVideo()">
                <video id="video-preview" controls style="max-width: 300px; display: none;"></video>
            </div>

            <div id="text-section" style="display: none;">
                <label for="text-description">إدخال نص:</label>
                <textarea id="text-description" placeholder="أدخل وصف البيانات"></textarea>
            </div>
        </form>
    </section>

    <nav>
        <ul>
            <li><a href="../index.html">🔗 العودة إلى الصفحة الرئيسية</a></li>
            <li><a href="dashboard.html">⚙️ لوحة التحكم</a></li>
            <li><a href="updates.html">🔄 آخر التحديثات</a></li>
        </ul>
    </nav>

    <script>
        function toggleInput() {
            document.getElementById("image-section").style.display = document.getElementById("use-image").checked ? "block" : "none";
            document.getElementById("video-section").style.display = document.getElementById("use-video").checked ? "block" : "none";
            document.getElementById("text-section").style.display = document.getElementById("use-text").checked ? "block" : "none";
        }

        function previewImage() {
            const input = document.getElementById("image-upload");
            const preview = document.getElementById("image-preview");
            if (input.files && input.files[0]) {
                const reader = new FileReader();
                reader.onload = function(e) {
                    preview.src = e.target.result;
                    preview.style.display = "block";
                };
                reader.readAsDataURL(input.files[0]);
            }
        }

        function previewVideo() {
            const input = document.getElementById("video-upload");
            const preview = document.getElementById("video-preview");
            if (input.files && input.files[0]) {
                const reader = new FileReader();
                reader.onload = function(e) {
                    preview.src = e.target.result;
                    preview.style.display = "block";
                };
                reader.readAsDataURL(input.files[0]);
            }
        }
    </script>

</body>
</html>
"""

for path in file_paths:
    with open(path, "w") as file:
        file.write(new_content)

print("✅ تم تحديث الصفحات بنجاح في:", file_paths)

# %%
import os

# قائمة بالمسارات التي سيتم تحديثها
file_paths = [
    "/mnt/c/Users/ali/Desktop/STEAM_Nexus_Hub/Classification_of_flower_structure_TM1/index.html",
    "/mnt/c/Users/ali/Desktop/STEAM_Nexus_Hub/Plant_Recognition_Lab/index.html"
]

# المحتوى الجديد للصفحات
new_content = """<!DOCTYPE html>
<html lang="ar">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>إعداد المشروع - تخصيص النموذج</title>
    <link rel="stylesheet" href="styles.css">
</head>
<body>

    <header>
        <h1>إعداد المشروع - اختيار النموذج</h1>
        <p>قم بتخصيص طريقة تشغيل المشروع وفق احتياجاتك.</p>
    </header>

    <marquee direction='right' scrollamount='5'>
        🎉 مرحبًا بك في مشاريع الذكاء الصناعي! اختر إعدادات التشغيل وقم بتحليل البيانات بسهولة. 🚀
    </marquee>

    <section>
        <h2>إعدادات التنفيذ</h2>
        <form>
            <label for='execution-selection'>اختر طريقة التنفيذ:</label>
            <select id='execution-selection'>
                <option value='gpu-high-accuracy'>GPU - دقة عالية</option>
                <option value='cpu-balanced'>CPU - متوازن</option>
                <option value='system-32'>نظام 32 - تحليل دقيق</option>
                <option value='system-64'>نظام 64 - أداء سريع</option>
            </select>
        </form>
    </section>

    <section>
        <h2>رفع البيانات</h2>
        <form>
            <label>حدد نوع البيانات:</label><br>
            <input type='checkbox' id='use-image' onchange='toggleInput()'> صورة  
            <input type='checkbox' id='use-video' onchange='toggleInput()'> فيديو  
            <input type='checkbox' id='use-text' onchange='toggleInput()'> نص  
            <br><br>

            <div id='image-section' style='display: none;'>
                <label for='image-upload'>تحميل صورة:</label>
                <input type='file' id='image-upload' accept='image/*' onchange='previewImage()'>
                <img id='image-preview' style='max-width: 300px; display: none;'>
            </div>

            <div id='video-section' style='display: none;'>
                <label for='video-upload'>تحميل فيديو:</label>
                <input type='file' id='video-upload' accept='video/*' onchange='previewVideo()'>
                <video id='video-preview' controls style='max-width: 300px; display: none;'></video>
            </div>

            <div id='text-section' style='display: none;'>
                <label for='text-description'>إدخال نص:</label>
                <textarea id='text-description' placeholder='أدخل وصف البيانات'></textarea>
            </div>
        </form>
    </section>

    <nav>
        <ul>
            <li><a href='../index.html'>🔗 العودة إلى الصفحة الرئيسية</a></li>
            <li><a href='dashboard.html'>⚙️ لوحة التحكم</a></li>
            <li><a href='updates.html'>🔄 آخر التحديثات</a></li>
        </ul>
    </nav>

    <section>
        <h2>تشغيل الكود</h2>
        <button onclick='runCode()'>🚀 تشغيل الكود</button>
    </section>

    <script>
        function toggleInput() {
            document.getElementById('image-section').style.display = document.getElementById('use-image').checked ? 'block' : 'none';
            document.getElementById('video-section').style.display = document.getElementById('use-video').checked ? 'block' : 'none';
            document.getElementById('text-section').style.display = document.getElementById('use-text').checked ? 'block' : 'none';
        }

        function runCode() {
            alert('🚀 يتم تشغيل الكود بناءً على الإعدادات المختارة!');
        }
    </script>

</body>
</html>
"""

# تنفيذ التحديثات داخل المستودعات الفرعية
for path in file_paths:
    with open(path, "w", encoding="utf-8") as file:
        file.write(new_content)

print("✅ تم تحديث الصفحات بنجاح في:", file_paths)

# %%
import os

# قائمة بالمسارات التي سيتم تحديثها أو إنشاؤها
file_paths = [
    "/mnt/c/Users/ali/Desktop/STEAM_Nexus_Hub/Classification_of_flower_structure_TM1/index.html",
    "/mnt/c/Users/ali/Desktop/STEAM_Nexus_Hub/Plant_Recognition_Lab/index.html"
]

# المحتوى الجديد للصفحات
new_content = """<!DOCTYPE html>
<html lang="ar">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>إعداد المشروع - تخصيص النموذج</title>
    <link rel="stylesheet" href="styles.css">
</head>
<body>

    <header>
        <h1>إعداد المشروع - اختيار النموذج</h1>
        <p>قم بتخصيص طريقة تشغيل المشروع وفق احتياجاتك.</p>
    </header>

    <marquee direction='right' scrollamount='5'>
        🎉 مرحبًا بك في مشاريع الذكاء الصناعي! اختر إعدادات التشغيل وقم بتحليل البيانات بسهولة. 🚀
    </marquee>

    <section>
        <h2>إعدادات التنفيذ</h2>
        <form>
            <label for='execution-selection'>اختر طريقة التنفيذ:</label>
            <select id='execution-selection'>
                <option value='gpu-high-accuracy'>GPU - دقة عالية</option>
                <option value='cpu-balanced'>CPU - متوازن</option>
                <option value='system-32'>نظام 32 - تحليل دقيق</option>
                <option value='system-64'>نظام 64 - أداء سريع</option>
            </select>
        </form>
    </section>

    <section>
        <h2>رفع البيانات</h2>
        <form>
            <label>حدد نوع البيانات:</label><br>
            <input type='checkbox' id='use-image' onchange='toggleInput()'> صورة  
            <input type='checkbox' id='use-video' onchange='toggleInput()'> فيديو  
            <input type='checkbox' id='use-text' onchange='toggleInput()'> نص  
            <br><br>

            <div id='image-section' style='display: none;'>
                <label for='image-upload'>تحميل صورة:</label>
                <input type='file' id='image-upload' accept='image/*' onchange='previewImage()'>
                <img id='image-preview' style='max-width: 300px; display: none;'>
            </div>

            <div id='video-section' style='display: none;'>
                <label for='video-upload'>تحميل فيديو:</label>
                <input type='file' id='video-upload' accept='video/*' onchange='previewVideo()'>
                <video id='video-preview' controls style='max-width: 300px; display: none;'></video>
            </div>

            <div id='text-section' style='display: none;'>
                <label for='text-description'>إدخال نص:</label>
                <textarea id='text-description' placeholder='أدخل وصف البيانات'></textarea>
            </div>
        </form>
    </section>

    <nav>
        <ul>
            <li><a href='../index.html'>🔗 العودة إلى الصفحة الرئيسية</a></li>
            <li><a href='dashboard.html'>⚙️ لوحة التحكم</a></li>
            <li><a href='updates.html'>🔄 آخر التحديثات</a></li>
        </ul>
    </nav>

    <section>
        <h2>تشغيل الكود</h2>
        <button onclick='runCode()'>🚀 تشغيل الكود</button>
    </section>

    <script>
        function toggleInput() {
            document.getElementById('image-section').style.display = document.getElementById('use-image').checked ? 'block' : 'none';
            document.getElementById('video-section').style.display = document.getElementById('use-video').checked ? 'block' : 'none';
            document.getElementById('text-section').style.display = document.getElementById('use-text').checked ? 'block' : 'none';
        }

        function runCode() {
            alert('🚀 يتم تشغيل الكود بناءً على الإعدادات المختارة!');
        }
    </script>

</body>
</html>
"""

# تنفيذ التحديثات داخل المستودعات الفرعية أو إنشاء الملفات إذا لم تكن موجودة
for path in file_paths:
    dir_path = os.path.dirname(path)
    if not os.path.exists(dir_path):
        os.makedirs(dir_path)  # إنشاء المجلد إذا لم يكن موجودًا

    with open(path, "w", encoding="utf-8") as file:
        file.write(new_content)

print("✅ تم تحديث الصفحات وإنشاء أي ملفات مفقودة بنجاح في:", file_paths)

# %%
import os

# تحديد المسار لملف التحديثات
file_path = "/mnt/c/Users/ali/Desktop/STEAM_Nexus_Hub/updates.html"

# المحتوى الجديد للصفحة
new_content = """<!DOCTYPE html>
<html lang="ar">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>آخر التحديثات - STEAM Nexus Hub</title>
    <link rel="stylesheet" href="styles.css">
</head>
<body>

    <header>
        <h1>🔄 آخر التحديثات</h1>
        <p>هنا يمكنك متابعة أحدث التعديلات والتحسينات داخل المشروع.</p>
    </header>

    <section>
        <h2>📢 تحديثات حديثة</h2>
        <ul>
            <li>✅ تحسين أداء النظام باستخدام `GPU - دقة عالية`.</li>
            <li>🚀 تحديث تصميم `index.html` وإضافة زر تشغيل الكود.</li>
            <li>🔧 إصلاح الروابط الداخلية وتحسين التكامل بين المستودعات الفرعية.</li>
        </ul>
    </section>

    <nav>
        <ul>
            <li><a href="index.html">🔙 العودة إلى الصفحة الرئيسية</a></li>
            <li><a href="dashboard.html">⚙️ لوحة التحكم</a></li>
        </ul>
    </nav>

</body>
</html>
"""

# تنفيذ الإنشاء أو التحديث
dir_path = os.path.dirname(file_path)
if not os.path.exists(dir_path):
    os.makedirs(dir_path)  # إنشاء المجلد إذا لم يكن موجودًا

with open(file_path, "w", encoding="utf-8") as file:
    file.write(new_content)

print("✅ تم إنشاء `updates.html` داخل `STEAM_Nexus_Hub` بنجاح!")

# %%
import os

# تحديد المسار الرئيسي
hub_path = r"C:\Users\ali\Desktop\STEAM_Nexus_Hub"

# استعراض الملفات والمجلدات
def list_structure(path, indent=0):
    for item in os.listdir(path):
        full_path = os.path.join(path, item)
        if os.path.isdir(full_path):
            print("📂 " + "    " * indent + item)
            list_structure(full_path, indent + 1)
        else:
            print("📄 " + "    " * indent + item)

# تنفيذ الفحص
print(f"🚀 هيكلية {hub_path}:")
list_structure(hub_path)

# %%
import os

hub_path = "/mnt/c/Users/ali/Desktop/STEAM_Nexus_Hub"

def list_structure(path, indent=0):
    try:
        for item in os.listdir(path):
            full_path = os.path.join(path, item)
            if os.path.isdir(full_path):
                print(" " * indent + item)
                list_structure(full_path, indent + 1)
            else:
                print(" " * indent + item)
    except FileNotFoundError:
        print("المسار غير موجود:", path)

print("هيكلية", hub_path)
list_structure(hub_path)

# %%
import os

lab_path = "/mnt/c/Users/ali/Desktop/STEAM_Nexus_Hub/Classification_of_flower_structure_TM1/Plant_Recognition_Lab"

def list_structure(path, indent=0):
    try:
        for item in os.listdir(path):
            full_path = os.path.join(path, item)
            if os.path.isdir(full_path):
                print(" " * indent + item)
                list_structure(full_path, indent + 1)
            else:
                print(" " * indent + item)
    except FileNotFoundError:
        print("المسار غير موجود:", path)

print("هيكلية", lab_path)
list_structure(lab_path)

# %%
import os

ml_path = "/mnt/c/Users/ali/Desktop/intro-to-ml-tensorflow"

def list_structure(path, indent=0):
    try:
        for item in os.listdir(path):
            full_path = os.path.join(path, item)
            if os.path.isdir(full_path):
                print(" " * indent + item)
                list_structure(full_path, indent + 1)
            else:
                print(" " * indent + item)
    except FileNotFoundError:
        print("المسار غير موجود:", path)

print("هيكلية", ml_path)
list_structure(ml_path)

# %%
import os

classifier_path = "/mnt/c/Users/ali/Desktop/intro-to-ml-tensorflow/projects/p2_image_classifier"

def list_structure(path, indent=0):
    try:
        for item in os.listdir(path):
            full_path = os.path.join(path, item)
            if os.path.isdir(full_path):
                print(" " * indent + item)
                list_structure(full_path, indent + 1)
            else:
                print(" " * indent + item)
    except FileNotFoundError:
        print("المسار غير موجود:", path)

print("هيكلية", classifier_path)
list_structure(classifier_path)

# %%
import os

classifier_path = "/mnt/c/Users/ali/Desktop/intro-to-ml-tensorflow/projects/p2_image_classifier"

def list_structure(path, indent=0):
    try:
        for item in os.listdir(path):
            full_path = os.path.join(path, item)
            if os.path.isdir(full_path):
                print(" " * indent + item)
                list_structure(full_path, indent + 1)
            else:
                print(" " * indent + item)
    except FileNotFoundError:
        print("المسار غير موجود:", path)

print("هيكلية", classifier_path)
list_structure(classifier_path)

# %%
import os

# تحديث المسار لضمان التوافق مع نظام ملفات Linux داخل Windows (WSL أو Jupyter)
project_path = "/mnt/c/Users/ali/Desktop/STEAM_Nexus_Hub/Classification_of_flower_structure_TM1/Plant_Recognition_Lab"

def list_structure(path, indent=0):
    if os.path.exists(path):
        for item in os.listdir(path):
            full_path = os.path.join(path, item)
            if os.path.isdir(full_path):
                print(" " * indent + item + "/")
                list_structure(full_path, indent + 4)
            else:
                print(" " * indent + item)
    else:
        print("❌ المسار غير موجود، تحقق من صحة المسار:", path)

print("  استكشاف هيكلية المشروع داخل:", project_path)
list_structure(project_path)

# %%
import os

# تحديد المسار الرئيسي للمشروع
project_path = "/mnt/c/Users/ali/Desktop/STEAM_Nexus_Hub/Classification_of_flower_structure_TM1/Plant_Recognition_Lab"

# إنشاء المجلدات الأساسية داخل المستودع
folders = [
    "notebooks",
    "models",
    "data",
    "scripts",
    "docs/setup",
    "assets"
]

for folder in folders:
    os.makedirs(os.path.join(project_path, folder), exist_ok=True)

print("✅ تم إنشاء هيكلية المشروع بنجاح!")

# %%
import os

project_path = "/mnt/c/Users/ali/Desktop/STEAM_Nexus_Hub/Classification_of_flower_structure_TM1/Plant_Recognition_Lab"

def verify_structure(path):
    expected_folders = ["notebooks", "models", "data", "scripts", "docs/setup", "assets"]
    missing_folders = [folder for folder in expected_folders if not os.path.exists(os.path.join(path, folder))]

    if missing_folders:
        print("المجلدات التالية غير موجودة:", missing_folders)
    else:
        print("تم التحقق من الهيكلية، وجميع المجلدات موجودة.")

verify_structure(project_path)

# %%
import os

project_path = "/mnt/c/Users/ali/Desktop/STEAM_Nexus_Hub/Classification_of_flower_structure_TM1/Plant_Recognition_Lab"

def verify_structure(path):
    expected_folders = ["notebooks", "models", "data", "scripts", "docs/setup", "assets"]
    existing_folders = [folder for folder in expected_folders if os.path.exists(os.path.join(path, folder))]

    if existing_folders:
        print("🔹 المجلدات الموجودة داخل المشروع:")
        for folder in existing_folders:
            print("-", folder)
    else:
        print("❌ لم يتم العثور على أي من المجلدات المتوقعة.")

verify_structure(project_path)

# %%
import os

project_path = "/mnt/c/Users/ali/Desktop/STEAM_Nexus_Hub/Classification_of_flower_structure_TM1/Plant_Recognition_Lab"

def list_full_structure(path, indent=0):
    if os.path.exists(path):
        for item in sorted(os.listdir(path)):  # ترتيب العناصر لسهولة القراءة
            full_path = os.path.join(path, item)
            if os.path.isdir(full_path):
                print(" " * indent + item + "/")
                list_full_structure(full_path, indent + 4)
            else:
                print(" " * indent + item)
    else:
        print("  المسار غير موجود، تحقق من صحة المسار:", path)

print(" استعراض الهيكلية الكاملة للمشروع داخل:", project_path)
list_full_structure(project_path)

# %%
import subprocess

predict_script = os.path.join(project_path, "scripts/predict.py")

if os.path.exists(predict_script):
    result = subprocess.run(["python3", predict_script], capture_output=True, text=True)
    print(" تشغيل `predict.py`:")
    print(result.stdout)
else:
    print(" `predict.py` غير موجود داخل `scripts/`، تأكد من إضافته.")

# %%
import os

script_path = "/mnt/c/Users/ali/Desktop/STEAM_Nexus_Hub/Classification_of_flower_structure_TM1/Plant_Recognition_Lab/scripts/predict.py"

# التأكد من وجود المجلد
os.makedirs(os.path.dirname(script_path), exist_ok=True)

# إنشاء `predict.py` وإضافة كود مبدئي لتنفيذ النموذج
predict_code = """import tensorflow as tf
import numpy as np
from PIL import Image
import json
import sys

# تحميل النموذج المدرب
model_path = "../models/model_final.h5"
model = tf.keras.models.load_model(model_path)

# تحميل تصنيفات الأنواع
label_map_path = "../data/label_map.json"
with open(label_map_path, "r") as file:
    label_map = json.load(file)

def predict_image(image_path):
    image = Image.open(image_path).resize((224, 224))
    img_array = np.expand_dims(np.array(image) / 255.0, axis=0)
    
    predictions = model.predict(img_array)
    predicted_class = np.argmax(predictions)

    return label_map[str(predicted_class)]

if __name__ == "__main__":
    if len(sys.argv) < 2:
        print("❌ الرجاء إدخال مسار الصورة.")
    else:
        image_path = sys.argv[1]
        print("🚀 التصنيف:", predict_image(image_path))
"""

# كتابة الملف داخل `scripts/`
with open(script_path, "w") as file:
    file.write(predict_code)

print("✅ تم إنشاء `predict.py` داخل `scripts/`!")

# %%
import subprocess

image_test_path = "/mnt/c/Users/ali/Desktop/STEAM_Nexus_Hub/Classification_of_flower_structure_TM1/Plant_Recognition_Lab/data/test_images/sample_flower.jpg"
predict_script = "/mnt/c/Users/ali/Desktop/STEAM_Nexus_Hub/Classification_of_flower_structure_TM1/Plant_Recognition_Lab/scripts/predict.py"

result = subprocess.run(["python3", predict_script, image_test_path], capture_output=True, text=True)
print(result.stdout)

# %%
conda list --explicit | grep -v 'pinned'

# %%
conda list | awk '$4 == "" {print $1, $2}'

# %%
conda list --user

# %%
conda list --user

# %%
# !conda list --revisions

# %%
# !conda list | awk '$4 == "" {print $1, $2}'

# %%
# !pip list --not-required --format=freeze

# %%
conda list | awk '$4 == "" {print $1, $2}'

# %%
# !conda list | awk '$4 == "" {print $1, $2}'

# %%
conda list --revisions

# %%
import os

project_path = "/mnt/c/Users/ali/Desktop/STEAM_Nexus_Hub/Classification_of_flower_structure_TM1/Plant_Recognition_Lab"
existing_items = os.listdir(project_path)

required_files = ["README.md", "environment.yml", "requirements.txt"]
required_dirs = ["data", "notebooks", "models", "src", "configs", "outputs"]

# تحديد الملفات والمجلدات الناقصة
missing_files = [f for f in required_files if f not in existing_items]
missing_dirs = [d for d in required_dirs if d not in existing_items]

# إنشاء الملفات والمجلدات الناقصة
for d in missing_dirs:
    os.makedirs(os.path.join(project_path, d), exist_ok=True)

for f in missing_files:
    open(os.path.join(project_path, f), "w").close()

print("✅ تمت إضافة الملفات والمجلدات الناقصة!")

# %% [raw]
# import os
#
# project_path = "/mnt/c/Users/ali/Desktop/STEAM_Nexus_Hub/Classification_of_flower_structure_TM1/Plant_Recognition_Lab"
# existing_items = os.listdir(project_path)
#
# print("📂 المجلدات والملفات الحالية:")
# for item in existing_items:
#     print(f"  ├── {item}")

# %%
required_dirs = ["data", "notebooks", "models", "src", "configs", "outputs"]
required_files = ["README.md", "environment.yml", "requirements.txt"]

for d in required_dirs:
    os.makedirs(os.path.join(project_path, d), exist_ok=True)

for f in required_files:
    open(os.path.join(project_path, f), "w").close()

print("✅ تم إنشاء جميع المجلدات والملفات الناقصة!")

# %%
import shutil

# مسار الملف الأصلي
source_file = r"C:\Users\ali\Desktop\intro-to-ml-tensorflow\projects\p2_image_classifier\.ipynb_checkpoints\Project_Image_Classifier_Project-checkpoint.ipynb"

# مسار مجلد المشروع
destination_folder = r"C:\Users\ali\Desktop\STEAM_Nexus_Hub\Classification_of_flower_structure_TM1\Plant_Recognition_Lab"

# نسخ الملف
shutil.copy(source_file, destination_folder)

print("✅ تم نسخ الملف بنجاح إلى مجلد المشروع!")

# %%
cp /mnt/c/Users/ali/Desktop/intro-to-ml-tensorflow/projects/p2_image_classifier/.ipynb_checkpoints/Project_Image_Classifier_Project-checkpoint.ipynb \
   /mnt/c/Users/ali/Desktop/STEAM_Nexus_Hub/Classification_of_flower_structure_TM1/Plant_Recognition_Lab/

# %%
import shutil

source_file = "/mnt/c/Users/ali/Desktop/intro-to-ml-tensorflow/projects/p2_image_classifier/.ipynb_checkpoints/Project_Image_Classifier_Project-checkpoint.ipynb"
destination_folder = "/mnt/c/Users/ali/Desktop/STEAM_Nexus_Hub/Classification_of_flower_structure_TM1/Plant_Recognition_Lab"

shutil.copy(source_file, destination_folder)
print("✅ تم نسخ الملف بنجاح!")

# %%
 import os

# تحديد المجلد الذي يحتوي على الملفات
notebook_dir = "/mnt/c/Users/ali/Desktop/STEAM_Nexus_Hub/Classification_of_flower_structure_TM1/Plant_Recognition_Lab"

# عرض جميع الملفات داخل المجلد
files = os.listdir(notebook_dir)
print(" الملفات المتاحة داخل المجلد:")
for file in files:
    print(file)

# %%
# !conda search ipywidgets -c conda-forge

# %%
import ipywidgets as widgets
print("✅ ipywidgets مثبت ويعمل!")
