# %% [markdown]
# # Your First AI application
#
# Going forward, AI algorithms will be incorporated into more and more everyday applications. For example, you might want to include an image classifier in a smart phone app. To do this, you'd use a deep learning model trained on hundreds of thousands of images as part of the overall application architecture. A large part of software development in the future will be using these types of models as common parts of applications.
#
# In this project, you'll train an image classifier to recognize different species of flowers. You can imagine using something like this in a phone app that tells you the name of the flower your camera is looking at. In practice you'd train this classifier, then export it for use in your application. We'll be using [this dataset](http://www.robots.ox.ac.uk/~vgg/data/flowers/102/index.html) from Oxford of 102 flower categories, you can see a few examples below.
#
# <img src='assets/Flowers.png' width=500px>
#
# The project is broken down into multiple steps:
#
# * Load the image dataset and create a pipeline.
# * Build and Train an image classifier on this dataset.
# * Use your trained model to perform inference on flower images.
#
# We'll lead you through each part which you'll implement in Python.
#
# When you've completed this project, you'll have an application that can be trained on any set of labeled images. Here your network will be learning about flowers and end up as a command line application. But, what you do with your new skills depends on your imagination and effort in building a dataset. For example, imagine an app where you take a picture of a car, it tells you what the make and model is, then looks up information about it. Go build your own dataset and make something new.

# %% [markdown]
# ## Import Resources

# %% [markdown]
# # TODO: Make all necessary imports.import os
# import json
# from PIL import Image
# import tensorflow as tf
# import tensorflow_datasets as tfds
# import tensorflow_hub as hub
# import numpy as np
# import matplotlib.pyplot as plt
# import ipywidgets as widgets
# import imageio
# import torchvision
# import torchvision.transforms as transforms
# import dill
# import etils
# import promise
# import tensorflow_metadata

# %%
# !which python
# Out:
# /home/ali/anaconda3/envs/sf_env/bin/python

# %%
# استيراد المكتبات الأساسية
import os
import json
import tensorflow as tf
import tensorflow_datasets as tfds
import tensorflow_hub as hub
import numpy as np
import matplotlib.pyplot as plt
import ipywidgets as widgets
import imageio
import torchvision
import torchvision.transforms as transforms
import scipy
import pandas as pd
import seaborn as sns
import tqdm
import yaml
import h5py

print("✅ المكتبات الأساسية استُوردت بنجاح!")

# استيراد المكتبات المحتملة لحدوث خطأ بشكل منفصل
problematic_libs = [
    "albumentations", "sklearn", "googleapis_common_protos",
    "semantic_kernel", "spoonacular", "ruamel.yaml", "pydantic",
    "dill", "segno", "qrcode", "cv2"
]

for lib in problematic_libs:
    try:
        __import__(lib)
        print(f"✅ {lib} استُوردت بنجاح!")
    except ModuleNotFoundError:
        print(f"مكتبة غير مثبتة: {lib}. جرب تثبيتها باستخدام `pip install {lib}`")

print("كل المكتبات المتاحة الآن جاهزة للاستخدام!")
# Out:
# ✅ المكتبات الأساسية استُوردت بنجاح!
# مكتبة غير مثبتة: albumentations. جرب تثبيتها باستخدام `pip install albumentations`
# ✅ sklearn استُوردت بنجاح!
# مكتبة غير مثبتة: googleapis_common_protos. جرب تثبيتها باستخدام `pip install googleapis_common_protos`
# ✅ semantic_kernel استُوردت بنجاح!
# ✅ spoonacular استُوردت بنجاح!
# ✅ ruamel.yaml استُوردت بنجاح!
# ✅ pydantic استُوردت بنجاح!
# ✅ dill استُوردت بنجاح!
# ✅ segno استُوردت بنجاح!
# ✅ qrcode استُوردت بنجاح!
# ✅ cv2 استُوردت بنجاح!
# كل المكتبات المتاحة الآن جاهزة للاستخدام!

# %%
import segno

# %%
import cupy

# %%
import googleapis_common_protos
import dill
import segno

print(" جميع المكتبات تعمل بنجاح داخل البيئة المحلية!")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 import googleapis_common_protos
#       2 import dill
#       3 import segno
#
# ModuleNotFoundError: No module named 'googleapis_common_protos'

# %% [markdown]
# ## Load the Dataset
#
# Here you'll use `tensorflow_datasets` to load the [Oxford Flowers 102 dataset](https://www.tensorflow.org/datasets/catalog/oxford_flowers102). This dataset has 3 splits: `'train'`, `'test'`, and `'validation'`.  You'll also need to make sure the training data is normalized and resized to 224x224 pixels as required by the pre-trained networks.
#
# The validation and testing sets are used to measure the model's performance on data it hasn't seen yet, but you'll still need to normalize and resize the images to the appropriate size.

# %% [raw]
# # TODO: Load the dataset with TensorFlow Datasets.
#
# # TODO: Create a training set, a validation set and a test set.
# import tensorflow as tf
# import tensorflow_datasets as tfds
# import os
#
# # تحديد مسار المشروع
# project_path = "C:/Users/ali/Desktop/STEAM_Nexus_Hub/Classification_of_flower_structure_TM1/Plant_Recognition_Lab/"
#
# # تحميل بيانات Oxford Flowers 102 داخل المشروع
# dataset, info = tfds.load(
#     "oxford_flowers102",
#     data_dir=f"{project_path}Dataset_Source",
#     as_supervised=True,
#     with_info=True,
#     download=True  # تحميل البيانات إذا لم تكن موجودة
# )
#
# # تقسيم البيانات
# train_ds, val_ds, test_ds = dataset["train"], dataset["validation"], dataset["test"]
#
# # دالة معالجة الصور (تغيير الحجم + تطبيع)
# def preprocess_image(image, label):
#     image = tf.image.resize(image, (224, 224))  # تغيير الحجم إلى 224x224
#     image = tf.cast(image, tf.float32) / 255.0  # تطبيع القيم بين 0 و 1
#     return image, label
#
# # تطبيق المعالجة على كل مجموعة
# train_ds = train_ds.map(preprocess_image)
# val_ds = val_ds.map(preprocess_image)
# test_ds = test_ds.map(preprocess_image)
#
# print("تم تحميل ومعالجة بيانات Oxford Flowers 102 داخل المشروع بنجاح!")

# %%
import os
print(os.listdir("C:/Users/ali/Desktop/STEAM_Nexus_Hub/Classification_of_flower_structure_TM1/Plant_Recognition_Lab/Dataset_Source"))
# Out:
# ['downloads', 'oxford_flowers102']

# %%
import os
folder_path = "/mnt/c/Users/ali/Desktop/STEAM_Nexus_Hub/Classification_of_flower_structure_TM1/Plant_Recognition_Lab/C"
print("محتويات المجلد:")
print(os.listdir(folder_path))
# Out:
# محتويات المجلد:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 4
#       2 folder_path = "/mnt/c/Users/ali/Desktop/STEAM_Nexus_Hub/Classification_of_flower_structure_TM1/Plant_Recognition_Lab/C"
#       3 print("محتويات المجلد:")
# ----> 4 print(os.listdir(folder_path))
#
# FileNotFoundError: [Errno 2] No such file or directory: '/mnt/c/Users/ali/Desktop/STEAM_Nexus_Hub/Classification_of_flower_structure_TM1/Plant_Recognition_Lab/C'

# %%
import os
folder_path = "/mnt/c/Users/ali/Desktop/STEAM_Nexus_Hub/Classification_of_flower_structure_TM1/Plant_Recognition_Lab/C:"
try:
    files = os.listdir(folder_path)
    print(" الملفات والمجلدات داخل 'C:' داخل الدفتر:")
    for file in files:
        print(f" {file}")
except FileNotFoundError:
    print(" المسار المحدد غير موجود، تأكد من كتابة الاسم الصحيح أو وجود المجلد!")
# Out:
#  الملفات والمجلدات داخل 'C:' داخل الدفتر:
#  Users

# %% [markdown]
# ## Explore the Dataset

# %%
# TODO: Get the number of examples in each set from the dataset info.

# TODO: Get the number of classes in the dataset from the dataset info.
import tensorflow_datasets as tfds

# تحميل معلومات مجموعة بيانات Oxford Flowers 102
dataset_info = tfds.builder("oxford_flowers102").info

# استخراج عدد الأمثلة لكل مجموعة
num_train = dataset_info.splits["train"].num_examples
num_val = dataset_info.splits["validation"].num_examples
num_test = dataset_info.splits["test"].num_examples

# استخراج عدد الفئات
num_classes = dataset_info.features["label"].num_classes

# طباعة المعلومات
print(f"عدد العينات - تدريب: {num_train}, تحقق: {num_val}, اختبار: {num_test}")
print(f"عدد الفئات في مجموعة البيانات: {num_classes}")
# Out:
# عدد العينات - تدريب: 1020, تحقق: 1020, اختبار: 6149
# عدد الفئات في مجموعة البيانات: 102

# %%
# TODO: Print the shape and corresponding label of 3 images in the training set.
# اختيار 3 صور من مجموعة التدريب
sample_images = train_ds.take(3)

# استعراض شكل الصورة والتصنيف لكل واحدة
for image, label in sample_images:
    print(f" شكل الصورة: {image.shape}, التصنيف: {label.numpy()}")
# Out:
# 2025-06-01 13:11:32.182356: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: NOT_FOUND: C:/Users/ali/Desktop/STEAM_Nexus_Hub/Classification_of_flower_structure_TM1/Plant_Recognition_Lab/Dataset_Source/oxford_flowers102/2.1.1/oxford_flowers102-train.tfrecord-00000-of-00001; No such file or directory
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[13], line 6
#       3 sample_images = train_ds.take(3)
#       5 # استعراض شكل الصورة والتصنيف لكل واحدة
# ----> 6 for image, label in sample_images:
#       7     print(f" شكل الصورة: {image.shape}, التصنيف: {label.numpy()}")
#
# File ~/anaconda3/envs/sf_env/lib/python3.10/site-packages/tensorflow/python/data/ops/iterator_ops.py:809, in OwnedIterator.__next__(self)
#     807 def __next__(self):
#     808   try:
# --> 809     return self._next_internal()
# ...

# %%
import os

folder_path = "C:/Users/ali/Desktop/STEAM_Nexus_Hub/Classification_of_flower_structure_TM1/Plant_Recognition_Lab/Dataset_Source/oxford_flowers102/2.1.1/"
print(" الملفات داخل المجلد:")
print(os.listdir(folder_path))
# Out:
#  الملفات داخل المجلد:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[14], line 5
#       3 folder_path = "C:/Users/ali/Desktop/STEAM_Nexus_Hub/Classification_of_flower_structure_TM1/Plant_Recognition_Lab/Dataset_Source/oxford_flowers102/2.1.1/"
#       4 print(" الملفات داخل المجلد:")
# ----> 5 print(os.listdir(folder_path))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:/Users/ali/Desktop/STEAM_Nexus_Hub/Classification_of_flower_structure_TM1/Plant_Recognition_Lab/Dataset_Source/oxford_flowers102/2.1.1/'

# %%
import os

folder_path = "/mnt/c/Users/ali/Desktop/STEAM_Nexus_Hub/Classification_of_flower_structure_TM1/Plant_Recognition_Lab/Dataset_Source/"
print(" الملفات داخل `Dataset_Source` باستخدام `/mnt/`:")
print(os.listdir(folder_path))
# Out:
#  الملفات داخل `Dataset_Source` باستخدام `/mnt/`:
# ['downloads', 'oxford_flowers102']

# %%
import os

folder_path = "/mnt/c/Users/ali/Desktop/STEAM_Nexus_Hub/Classification_of_flower_structure_TM1/Plant_Recognition_Lab/Dataset_Source/oxford_flowers102/"
print(" الملفات داخل `oxford_flowers102`:")
print(os.listdir(folder_path))
# Out:
#  الملفات داخل `oxford_flowers102`:
# ['2.1.1']

# %%
import os

folder_path = "/mnt/c/Users/ali/Desktop/STEAM_Nexus_Hub/Classification_of_flower_structure_TM1/Plant_Recognition_Lab/Dataset_Source/oxford_flowers102/2.1.1/"
print(" الملفات داخل `2.1.1`:")
print(os.listdir(folder_path))
# Out:
#  الملفات داخل `2.1.1`:
# ['dataset_info.json', 'features.json', 'label.labels.txt', 'oxford_flowers102-test.tfrecord-00000-of-00002', 'oxford_flowers102-test.tfrecord-00001-of-00002', 'oxford_flowers102-train.tfrecord-00000-of-00001', 'oxford_flowers102-validation.tfrecord-00000-of-00001']

# %%
import tensorflow_datasets as tfds

# تحديد مسار المجلد الصحيح
dataset_dir = "/mnt/c/Users/ali/Desktop/STEAM_Nexus_Hub/Classification_of_flower_structure_TM1/Plant_Recognition_Lab/Dataset_Source/oxford_flowers102/2.1.1/"

# تحميل البيانات باستخدام المسار الصحيح
dataset, info = tfds.load("oxford_flowers102", data_dir=dataset_dir, as_supervised=True, with_info=True)

# طباعة معلومات عامة للتأكد من أن التحميل تم بنجاح
print(f"  عدد العينات - تدريب: {info.splits['train'].num_examples}, تحقق: {info.splits['validation'].num_examples}, اختبار: {info.splits['test'].num_examples}")
print(f"  عدد الفئات في مجموعة البيانات: {info.features['label'].num_classes}")
# Out:
# ...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Generating splits...:   0%|          | 0/3 [00:00<?, ? splits/s]
# Generating train examples...: 0 examples [00:00, ? examples/s]
# Shuffling /mnt/c/Users/ali/Desktop/STEAM_Nexus_Hub/Classification_of_flower_structure_TM1/Plant_Recognition_La…
# Generating test examples...: 0 examples [00:00, ? examples/s]
# Shuffling /mnt/c/Users/ali/Desktop/STEAM_Nexus_Hub/Classification_of_flower_structure_TM1/Plant_Recognition_La…
# Generating validation examples...: 0 examples [00:01, ? examples/s]
# ...

# %%
import shutil

folder_path = "/mnt/c/Users/ali/Desktop/STEAM_Nexus_Hub/Classification_of_flower_structure_TM1/Plant_Recognition_Lab/Dataset_Source/oxford_flowers102/"
shutil.rmtree(folder_path)  #  ا حذف كل الملفات داخل المجلد!

# %%
import os

dataset_path = "/mnt/c/Users/ali/Desktop/STEAM_Nexus_Hub/Classification_of_flower_structure_TM1/Plant_Recognition_Lab/Dataset_Source/"
print(" الملفات داخل `Dataset_Source` بعد الاستبدال:")
print(os.listdir(dataset_path))
# Out:
#  الملفات داخل `Dataset_Source` بعد الاستبدال:
# ['downloads']

# %%
import tensorflow_datasets as tfds

dataset_dir = "/mnt/c/Users/ali/Desktop/STEAM_Nexus_Hub/Classification_of_flower_structure_TM1/Plant_Recognition_Lab/Dataset_Source/"

dataset, info = tfds.load("oxford_flowers102", data_dir=dataset_dir, as_supervised=True, with_info=True, download=True)

print("  تم تحميل البيانات من جديد داخل `Dataset_Source`!")
# Out:
# ...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/3 [00:00<?, ? splits/s]
# Generating train examples...: 0 examples [00:00, ? examples/s]
# Shuffling /mnt/c/Users/ali/Desktop/STEAM_Nexus_Hub/Classification_of_flower_structure_TM1/Plant_Recognition_La…
# Generating test examples...: 0 examples [00:00, ? examples/s]
# Shuffling /mnt/c/Users/ali/Desktop/STEAM_Nexus_Hub/Classification_of_flower_structure_TM1/Plant_Recognition_La…
# Generating validation examples...: 0 examples [00:00, ? examples/s]
# Shuffling /mnt/c/Users/ali/Desktop/STEAM_Nexus_Hub/Classification_of_flower_structure_TM1/Plant_Recognition_La…
# Dataset oxford_flowers102 downloaded and prepared to /mnt/c/Users/ali/Desktop/STEAM_Nexus_Hub/Classification_of_flower_structure_TM1/Plant_Recognition_Lab/Dataset_Source/oxford_flowers102/2.1.1. Subsequent calls will reuse this data.
# ...

# %%
# TODO: Plot 1 image from the training set. Set the title 
# of the plot to the corresponding image label. 
import tensorflow_datasets as tfds
import matplotlib.pyplot as plt

# تحميل بيانات مجموعة التدريب
dataset_dir = "/mnt/c/Users/ali/Desktop/STEAM_Nexus_Hub/Classification_of_flower_structure_TM1/Plant_Recognition_Lab/Dataset_Source/"
dataset, info = tfds.load("oxford_flowers102", data_dir=dataset_dir, as_supervised=True, split="train")

# استخراج عينة واحدة من مجموعة التدريب
for image, label in dataset.take(1):
    plt.imshow(image.numpy())
    plt.title(f"Label: {label.numpy()}")
    plt.axis("off")
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 8
#       6 # تحميل بيانات مجموعة التدريب
#       7 dataset_dir = "/mnt/c/Users/ali/Desktop/STEAM_Nexus_Hub/Classification_of_flower_structure_TM1/Plant_Recognition_Lab/Dataset_Source/"
# ----> 8 dataset, info = tfds.load("oxford_flowers102", data_dir=dataset_dir, as_supervised=True, split="train")
#      10 # استخراج عينة واحدة من مجموعة التدريب
#      11 for image, label in dataset.take(1):
#
# ValueError: too many values to unpack (expected 2)

# %%
dataset = tfds.load("oxford_flowers102", data_dir=dataset_dir, as_supervised=True, split="train")

print(type(dataset))  # لمعرفة نوع الكائن المعاد
# Out:
# <class 'tensorflow.python.data.ops.prefetch_op._PrefetchDataset'>

# %%
import tensorflow_datasets as tfds
import matplotlib.pyplot as plt

# تحميل بيانات مجموعة التدريب
dataset_dir = "/mnt/c/Users/ali/Desktop/STEAM_Nexus_Hub/Classification_of_flower_structure_TM1/Plant_Recognition_Lab/Dataset_Source/"
dataset = tfds.load("oxford_flowers102", data_dir=dataset_dir, as_supervised=True, split="train")

# استخراج عينة واحدة من مجموعة التدريب
image, label = next(iter(dataset))  # استخدام `next(iter(dataset))` بدلاً من `for`

# عرض الصورة
plt.imshow(image.numpy())
plt.title(f"Label: {label.numpy()}")
plt.axis("off")
plt.show()

# %%
 # تحميل معلومات المجموعة
dataset_dir = "/mnt/c/Users/ali/Desktop/STEAM_Nexus_Hub/Classification_of_flower_structure_TM1/Plant_Recognition_Lab/Dataset_Source/"
dataset, info = tfds.load("oxford_flowers102", data_dir=dataset_dir, as_supervised=True, with_info=True, split="train")

# استخراج أسماء الفئات
label_names = info.features["label"].names

# استخراج عينة وعرض الصورة مع اسم الزهرة
image, label = next(iter(dataset))
flower_name = label_names[label.numpy()]

plt.imshow(image.numpy())
plt.title(f" {flower_name} (Label: {label.numpy()})")
plt.axis("off")
plt.show()

# %%
import json

label_map_path = "/mnt/c/Users/ali/Desktop/STEAM_Nexus_Hub/Classification_of_flower_structure_TM1/Plant_Recognition_Lab/label_map.json"

with open(label_map_path, "r") as f:
    label_map = json.load(f)

# تحليل هيكل القاموس
print(" عدد الفئات في `label_map.json`:", len(label_map))
print(" أمثلة على البيانات:")
print({k: label_map[k] for k in
# Out:
#   Cell In[26], line 11
#     print({k: label_map[k] for k in
#                                    ^
# SyntaxError: incomplete input

# %%
import json
import tensorflow_datasets as tfds
import matplotlib.pyplot as plt

# تحميل بيانات مجموعة التدريب
dataset_dir = "/mnt/c/Users/ali/Desktop/STEAM_Nexus_Hub/Classification_of_flower_structure_TM1/Plant_Recognition_Lab/Dataset_Source/"
dataset = tfds.load("oxford_flowers102", data_dir=dataset_dir, as_supervised=True, split="train")

# تحميل ملف `label_map.json`
label_map_path = "/mnt/c/Users/ali/Desktop/STEAM_Nexus_Hub/Classification_of_flower_structure_TM1/Plant_Recognition_Lab/label_map.json"

with open(label_map_path, "r") as f:
    label_map = json.load(f)

# استخراج أول صورة وعرضها مع اسم الفئة الصحيح
image, label = next(iter(dataset))
flower_name = label_map.get(str(label.numpy()), "Unknown")  # التأكد من أن التصنيف موجود في القاموس

plt.imshow(image.numpy())
plt.title(f"  {flower_name} (Label: {label.numpy()})")
plt.axis("off")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[27], line 12
#       9 # تحميل ملف `label_map.json`
#      10 label_map_path = "/mnt/c/Users/ali/Desktop/STEAM_Nexus_Hub/Classification_of_flower_structure_TM1/Plant_Recognition_Lab/label_map.json"
# ---> 12 with open(label_map_path, "r") as f:
#      13     label_map = json.load(f)
#      15 # استخراج أول صورة وعرضها مع اسم الفئة الصحيح
#
# File ~/anaconda3/envs/sf_env/lib/python3.10/site-packages/IPython/core/interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# ...

# %%
import os

folder_path = "/mnt/c/Users/ali/Desktop/STEAM_Nexus_Hub/Classification_of_flower_structure_TM1/Plant_Recognition_Lab/"
print("  الملفات داخل المجلد:")
print(os.listdir(folder_path))
# Out:
#   الملفات داخل المجلد:
# ['.git', '.github', '.ipynb_checkpoints', 'AI_Model_Training.ipynb', 'assets', 'ccc', 'configs', 'data', 'Dataset_Source', 'Data_Processing_Lab.ipynb', 'docs', 'environment.yml', 'environment_changes.log', 'environment_freeze.txt', 'environment_status.yaml', 'Experimental_Data_Source', 'Fast_Test.ipynb', 'index.html', 'models', 'notebooks', 'outputs', 'Project_Analysis.ipynb', 'Project_Image_Classifier_Project-checkpoint - Copy.txt', 'Project_Image_Classifier_Project-checkpoint.ipynb', 'Project_Setup.ipynb', 'README.md', 'requirements.txt', 'scripts', 'src']

# %% [markdown]
# ### Label Mapping
#
# You'll also need to load in a mapping from label to category name. You can find this in the file `label_map.json`. It's a JSON object which you can read in with the [`json` module](https://docs.python.org/3.7/library/json.html). This will give you a dictionary mapping the integer coded labels to the actual names of the flowers.

# %%
# TODO: Plot 1 image from the training set. Set the title 
# of the plot to the corresponding class name. 
import json
import tensorflow_datasets as tfds

# تحميل معلومات مجموعة البيانات
dataset_dir = "/mnt/c/Users/ali/Desktop/STEAM_Nexus_Hub/Classification_of_flower_structure_TM1/Plant_Recognition_Lab/Dataset_Source/"
_, info = tfds.load("oxford_flowers102", data_dir=dataset_dir, as_supervised=True, with_info=True)

# استخراج أسماء الفئات
label_map = {str(i): name for i, name in enumerate(info.features["label"].names)}

# مسار حفظ الملف
label_map_path = "/mnt/c/Users/ali/Desktop/STEAM_Nexus_Hub/Classification_of_flower_structure_TM1/Plant_Recognition_Lab/label_map.json"

# حفظ القاموس في ملف JSON
with open(label_map_path, "w") as f:
    json.dump(label_map, f, indent=4)

print(f" تم إنشاء `label_map.json` وحفظه في {label_map_path}!")
# Out:
#  تم إنشاء `label_map.json` وحفظه في /mnt/c/Users/ali/Desktop/STEAM_Nexus_Hub/Classification_of_flower_structure_TM1/Plant_Recognition_Lab/label_map.json!

# %% [markdown]
# ## Create Pipeline

# %%
# TODO: Create a pipeline for each set.
import tensorflow_datasets as tfds
import tensorflow as tf

# تحميل بيانات مجموعة الأزهار
dataset_dir = "/mnt/c/Users/ali/Desktop/STEAM_Nexus_Hub/Classification_of_flower_structure_TM1/Plant_Recognition_Lab/Dataset_Source/"
dataset_splits = tfds.load("oxford_flowers102", data_dir=dataset_dir, as_supervised=True, split=["train", "validation", "test"])

# دالة معالجة البيانات
def process_data(image, label):
    image = tf.image.resize(image, (224, 224))  # تغيير حجم الصورة
    image = tf.cast(image, tf.float32) / 255.0  # تطبيع الصورة
    return image, label

# تطبيق المسار على كل مجموعة بيانات
train_data = dataset_splits[0].map(process_data).batch(32).prefetch(tf.data.AUTOTUNE)
val_data = dataset_splits[1].map(process_data).batch(32).prefetch(tf.data.AUTOTUNE)
test_data = dataset_splits[2].map(process_data).batch(32).pref
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[30], line 18
#      16 train_data = dataset_splits[0].map(process_data).batch(32).prefetch(tf.data.AUTOTUNE)
#      17 val_data = dataset_splits[1].map(process_data).batch(32).prefetch(tf.data.AUTOTUNE)
# ---> 18 test_data = dataset_splits[2].map(process_data).batch(32).pref
#
# AttributeError: '_BatchDataset' object has no attribute 'pref'

# %% [markdown]
# # Build and Train the Classifier
#
# Now that the data is ready, it's time to build and train the classifier. You should use the MobileNet pre-trained model from TensorFlow Hub to get the image features. Build and train a new feed-forward classifier using those features.
#
# We're going to leave this part up to you. If you want to talk through it with someone, chat with your fellow students!
#
# Refer to the rubric for guidance on successfully completing this section. Things you'll need to do:
#
# * Load the MobileNet pre-trained network from TensorFlow Hub.
# * Define a new, untrained feed-forward network as a classifier.
# * Train the classifier.
# * Plot the loss and accuracy values achieved during training for the training and validation set.
# * Save your trained model as a Keras model.
#
# We've left a cell open for you below, but use as many as you need. Our advice is to break the problem up into smaller parts you can run separately. Check that each part is doing what you expect, then move on to the next. You'll likely find that as you work through each part, you'll need to go back and modify your previous code. This is totally normal!
#
# When training make sure you're updating only the weights of the feed-forward network. You should be able to get the validation accuracy above 70% if you build everything right.
#
# **Note for Workspace users:** One important tip if you're using the workspace to run your code: To avoid having your workspace disconnect during the long-running tasks in this notebook, please read in the earlier page in this lesson called Intro to GPU Workspaces about Keeping Your Session Active. You'll want to include code from the workspace_utils.py module. Also, If your model is over 1 GB when saved as a checkpoint, there might be issues with saving backups in your workspace. If your saved checkpoint is larger than 1 GB (you can open a terminal and check with `ls -lh`), you should reduce the size of your hidden layers and train again.

# %%
# TODO: Build and train your network.

# %%
# TODO: Plot the loss and accuracy values achieved during training for the training and validation set.

# %% [markdown]
# ## Testing your Network
#
# It's good practice to test your trained network on test data, images the network has never seen either in training or validation. This will give you a good estimate for the model's performance on completely new images. You should be able to reach around 70% accuracy on the test set if the model has been trained well.

# %%
# TODO: Print the loss and accuracy values achieved on the entire test set.

# %% [markdown]
# ## Save the Model
#
# Now that your network is trained, save the model so you can load it later for making inference. In the cell below save your model as a Keras model (*i.e.* save it as an HDF5 file).

# %%
# TODO: Save your trained model as a Keras model.

# %% [markdown]
# ## Load the Keras Model
#
# Load the Keras model you saved above.

# %%
# TODO: Load the Keras model

# %% [markdown]
# # Inference for Classification
#
# Now you'll write a function that uses your trained network for inference. Write a function called `predict` that takes an image, a model, and then returns the top $K$ most likely class labels along with the probabilities. The function call should look like:
#
# ```python
# probs, classes = predict(image_path, model, top_k)
# ```
#
# If `top_k=5` the output of the `predict` function should be something like this:
#
# ```python
# probs, classes = predict(image_path, model, 5)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```
#
# Your `predict` function should use `PIL` to load the image from the given `image_path`. You can use the [Image.open](https://pillow.readthedocs.io/en/latest/reference/Image.html#PIL.Image.open) function to load the images. The `Image.open()` function returns an `Image` object. You can convert this `Image` object to a NumPy array by using the `np.asarray()` function.
#
# The `predict` function will also need to handle pre-processing the input image such that it can be used by your model. We recommend you write a separate function called `process_image` that performs the pre-processing. You can then call the `process_image` function from the `predict` function.
#
# ### Image Pre-processing
#
# The `process_image` function should take in an image (in the form of a NumPy array) and return an image in the form of a NumPy array with shape `(224, 224, 3)`.
#
# First, you should convert your image into a TensorFlow Tensor and then resize it to the appropriate size using `tf.image.resize`.
#
# Second, the pixel values of the input images are typically encoded as integers in the range 0-255, but the model expects the pixel values to be floats in the range 0-1. Therefore, you'll also need to normalize the pixel values.
#
# Finally, convert your image back to a NumPy array using the `.numpy()` method.

# %%
# TODO: Create the process_image function

# %% [markdown]
# To check your `process_image` function we have provided 4 images in the `./test_images/` folder:
#
# * cautleya_spicata.jpg
# * hard-leaved_pocket_orchid.jpg
# * orange_dahlia.jpg
# * wild_pansy.jpg
#
# The code below loads one of the above images using `PIL` and plots the original image alongside the image produced by your `process_image` function. If your `process_image` function works, the plotted image should be the correct size.

# %%
from PIL import Image

image_path = './test_images/hard-leaved_pocket_orchid.jpg'
im = Image.open(image_path)
test_image = np.asarray(im)

processed_test_image = process_image(test_image)

fig, (ax1, ax2) = plt.subplots(figsize=(10,10), ncols=2)
ax1.imshow(test_image)
ax1.set_title('Original Image')
ax2.imshow(processed_test_image)
ax2.set_title('Processed Image')
plt.tight_layout()
plt.show()

# %% [markdown]
# Once you can get images in the correct format, it's time to write the `predict` function for making inference with your model.
#
# ### Inference
#
# Remember, the `predict` function should take an image, a model, and then returns the top $K$ most likely class labels along with the probabilities. The function call should look like:
#
# ```python
# probs, classes = predict(image_path, model, top_k)
# ```
#
# If `top_k=5` the output of the `predict` function should be something like this:
#
# ```python
# probs, classes = predict(image_path, model, 5)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```
#
# Your `predict` function should use `PIL` to load the image from the given `image_path`. You can use the [Image.open](https://pillow.readthedocs.io/en/latest/reference/Image.html#PIL.Image.open) function to load the images. The `Image.open()` function returns an `Image` object. You can convert this `Image` object to a NumPy array by using the `np.asarray()` function.
#
# **Note:** The image returned by the `process_image` function is a NumPy array with shape `(224, 224, 3)` but the model expects the input images to be of shape `(1, 224, 224, 3)`. This extra dimension represents the batch size. We suggest you use the `np.expand_dims()` function to add the extra dimension.

# %%
# TODO: Create the predict function

# %% [markdown]
# # Sanity Check
#
# It's always good to check the predictions made by your model to make sure they are correct. To check your predictions we have provided 4 images in the `./test_images/` folder:
#
# * cautleya_spicata.jpg
# * hard-leaved_pocket_orchid.jpg
# * orange_dahlia.jpg
# * wild_pansy.jpg
#
# In the cell below use `matplotlib` to plot the input image alongside the probabilities for the top 5 classes predicted by your model. Plot the probabilities as a bar graph. The plot should look like this:
#
# <img src='assets/inference_example.png' width=600px>
#
# You can convert from the class integer labels to actual flower names using `class_names`.

# %%
# TODO: Plot the input image along with the top 5 classes
